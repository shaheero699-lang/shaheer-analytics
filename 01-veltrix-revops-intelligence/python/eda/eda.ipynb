# %%
# Exploratory Data Analysis (EDA)

## Veltrix RevOps Intelligence

This notebook performs exploratory analysis on customer, subscription, product usage, sales pipeline, and support ticket datasets.

### Objectives
- Understand dataset structure
- Analyze customer distribution
- Identify trends and patterns
- Detect anomalies and missing values
- Generate business insights

# %%
import pandas as pd
import numpy as np

print("EDA Notebook Loaded Successfully")
# Out:
# EDA Notebook Loaded Successfully

# %%
import pandas as pd
import numpy as np

# Sample dataset for portfolio demonstration

customers = pd.DataFrame({
    'customer_id':[1,2,3,4,5],
    'customer_health_score':[95,72,48,88,65],
    'region':['US','EU','US','APAC','EU']
})

customers.head()
# Out:
#    customer_id  customer_health_score region
# 0            1                     95     US
# 1            2                     72     EU
# 2            3                     48     US
# 3            4                     88   APAC
# 4            5                     65     EU

# %%
customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   customer_id            5 non-null      int64
#  1   customer_health_score  5 non-null      int64
#  2   region                 5 non-null      object
# dtypes: int64(2), object(1)
# memory usage: 252.0+ bytes

# %%
customers.describe()
# Out:
#        customer_id  customer_health_score
# count     5.000000               5.000000
# mean      3.000000              73.600000
# std       1.581139              18.689569
# min       1.000000              48.000000
# 25%       2.000000              65.000000
# 50%       3.000000              72.000000
# 75%       4.000000              88.000000
# max       5.000000              95.000000
